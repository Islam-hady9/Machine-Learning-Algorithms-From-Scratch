# %%
# Gradient Descent for Linear Regression
# yhat = wx + b
# loss = (y-yhat)**2 / N
import numpy as np

# %%
# Initialise some parameters
x = np.random.randn(10,1)
y = 2*x + np.random.rand()
# Parameters
w = 0.0
b = 0.0
# Hyperparameter
learning_rate = 0.01

# %%
# Create gradient descent function
def descend(x, y, w, b, learning_rate):
    dldw = 0.0
    dldb = 0.0
    N = x.shape[0]
    # loss = (y-(wx+b))**2
    for xi, yi in zip(x,y):
        dldw += -2*xi*(yi-(w*xi+b))
        dldb += -2*(yi-(w*xi+b))
        # Make an update to the w parameter
        w = w - learning_rate*(1/N)*dldw
        b = b - learning_rate*(1/N)*dldb
    return w, b

# %%
# Iteratively make updates
for epoch in range(400):
    w, b = descend(x, y, w, b, learning_rate)
    yhat = w*x + b
    loss = np.divide(np.sum((y-yhat)**2, axis=0), x.shape[0])
    print(f'{epoch} loss is {loss}, parameters w:{w}, b:{b}')
# Out:
# 0 loss is [4.72829848], parameters w:[0.25762325], b:[-0.0231319]
# 1 loss is [3.58752083], parameters w:[0.48092339], b:[-0.03781434]
# 2 loss is [2.72920151], parameters w:[0.67459398], b:[-0.04575313]
# 3 loss is [2.08193494], parameters w:[0.84267442], b:[-0.04836137]
# 4 loss is [1.59265939], parameters w:[0.98864227], b:[-0.04680613]
# 5 loss is [1.22188704], parameters w:[1.11549258], b:[-0.04204803]
# 6 loss is [0.94018559], parameters w:[1.22580582], b:[-0.03487474]
# 7 loss is [0.72558079], parameters w:[1.32180612], b:[-0.02592917]
# 8 loss is [0.5616372], parameters w:[1.40541137], b:[-0.01573341]
# 9 loss is [0.43603853], parameters w:[1.47827603], b:[-0.00470882]
# 10 loss is [0.33953656], parameters w:[1.54182804], b:[0.00680699]
# 11 loss is [0.26517193], parameters w:[1.59730034], b:[0.01854587]
# 12 loss is [0.2076958], parameters w:[1.64575811], b:[0.03029711]
# 13 loss is [0.16314003], parameters w:[1.688122], b:[0.04189739]
# 14 loss is [0.12849721], parameters w:[1.72518819], b:[0.05322229]
# 15 loss is [0.10148216], parameters w:[1.75764561], b:[0.06417924]
# 16 loss is [0.08035387], parameters w:[1.78609071], b:[0.07470156]
# 17 loss is [0.06378218], parameters w:[1.81104015], b:[0.08474357]
# 18 loss is [0.05074803], parameters w:[1.83294182], b:[0.09427645]
# 19 loss is [0.04046839], parameters w:[1.85218415], b:[0.10328485]
# 20 loss is [0.03233984], parameters w:[1.86910429], b:[0.11176402]
# 21 loss is [0.02589601], parameters w:[1.88399503], b:[0.11971755]
# 22 loss is [0.02077535], parameters w:[1.89711083], b:[0.12715538]
# 23 loss is [0.01669679], parameters w:[1.90867297], b:[0.13409224]
# 24 loss is [0.01344113], parameters w:[1.91887405], b:[0.14054641]
# 25 loss is [0.01083697], parameters w:[1.9278818], b:[0.14653861]
# 26 loss is [0.00874987], parameters w:[1.9358424], b:[0.15209123]
# 27 loss is [0.0070741], parameters w:[1.94288337], b:[0.15722757]
# 28 loss is [0.0057263], parameters w:[1.94911601], b:[0.16197141]
# 29 loss is [0.00464054], parameters w:[1.95463755], b:[0.16634648]
# 30 loss is [0.00376458], parameters w:[1.959533], b:[0.17037622]
# 31 loss is [0.00305691], parameters w:[1.96387675], b:[0.1740835]
# 32 loss is [0.00248445], parameters w:[1.96773393], b:[0.17749042]
# 33 loss is [0.00202083], parameters w:[1.97116164], b:[0.18061821]
# 34 loss is [0.00164495], parameters w:[1.97420993], b:[0.18348712]
# 35 loss is [0.0013399], parameters w:[1.97692278], b:[0.18611637]
# 36 loss is [0.00109209], parameters w:[1.97933881], b:[0.18852411]
# 37 loss is [0.00089063], parameters w:[1.98149198], b:[0.19072742]
# 38 loss is [0.00072671], parameters w:[1.98341219], b:[0.19274233]
# 39 loss is [0.00059324], parameters w:[1.98512576], b:[0.19458382]
# 40 loss is [0.00048449], parameters w:[1.9866559], b:[0.19626587]
# 41 loss is [0.00039584], parameters w:[1.98802311], b:[0.19780146]
# 42 loss is [0.00032352], parameters w:[1.98924546], b:[0.19920266]
# 43 loss is [0.00026451], parameters w:[1.99033894], b:[0.20048066]
# 44 loss is [0.00021632], parameters w:[1.99131768], b:[0.20164579]
# 45 loss is [0.00017696], parameters w:[1.99219421], b:[0.2027076]
# 46 loss is [0.0001448], parameters w:[1.99297961], b:[0.20367489]
# 47 loss is [0.00011852], parameters w:[1.99368371], b:[0.20455578]
# 48 loss is [9.70206464e-05], parameters w:[1.99431524], b:[0.20535773]
# 49 loss is [7.94393878e-05], parameters w:[1.99488194], b:[0.20608759]
# 50 loss is [6.50556055e-05], parameters w:[1.99539069], b:[0.20675165]
# 51 loss is [5.32849036e-05], parameters w:[1.99584763], b:[0.2073557]
# 52 loss is [4.36504141e-05], parameters w:[1.9962582], b:[0.20790502]
# 53 loss is [3.57628314e-05], parameters w:[1.99662725], b:[0.20840445]
# 54 loss is [2.93041997e-05], parameters w:[1.99695911], b:[0.20885842]
# 55 loss is [2.40147358e-05], parameters w:[1.99725764], b:[0.209271]
# 56 loss is [1.96821106e-05], parameters w:[1.99752628], b:[0.20964588]
# 57 loss is [1.61327245e-05], parameters w:[1.99776809], b:[0.20998644]
# 58 loss is [1.3224601e-05], parameters w:[1.99798584], b:[0.21029579]
# 59 loss is [1.08415945e-05], parameters w:[1.99818198], b:[0.21057673]
# 60 loss is [8.88866701e-06], parameters w:[1.9983587], b:[0.21083184]
# 61 loss is [7.28803475e-06], parameters w:[1.99851797], b:[0.21106346]
# 62 loss is [5.97602213e-06], parameters w:[1.99866155], b:[0.21127372]
# 63 loss is [4.90049293e-06], parameters w:[1.99879102], b:[0.21146458]
# 64 loss is [4.0187517e-06], parameters w:[1.99890779], b:[0.21163779]
# 65 loss is [3.29582855e-06], parameters w:[1.99901314], b:[0.21179499]
# 66 loss is [2.70307703e-06], parameters w:[1.9991082], b:[0.21193762]
# 67 loss is [2.21702755e-06], parameters w:[1.999194], b:[0.21206704]
# 68 loss is [1.81844941e-06], parameters w:[1.99927145], b:[0.21218445]
# 69 loss is [1.4915834e-06], parameters w:[1.99934138], b:[0.21229097]
# 70 loss is [1.22351379e-06], parameters w:[1.99940452], b:[0.21238758]
# 71 loss is [1.00365424e-06], parameters w:[1.99946156], b:[0.21247521]
# 72 loss is [8.23326916e-07], parameters w:[1.99951308], b:[0.21255469]
# 73 loss is [6.7541783e-07], parameters w:[1.99955963], b:[0.21262677]
# 74 loss is [5.54094581e-07], parameters w:[1.99960169], b:[0.21269213]
# 75 loss is [4.54575138e-07], parameters w:[1.99963971], b:[0.2127514]
# 76 loss is [3.72938425e-07], parameters w:[1.99967407], b:[0.21280514]
# 77 loss is [3.0596912e-07], parameters w:[1.99970513], b:[0.21285387]
# 78 loss is [2.51030483e-07], parameters w:[1.99973321], b:[0.21289805]
# 79 loss is [2.0596013e-07], parameters w:[1.9997586], b:[0.2129381]
# 80 loss is [1.68984611e-07], parameters w:[1.99978155], b:[0.21297441]
# 81 loss is [1.38649394e-07], parameters w:[1.99980232], b:[0.21300733]
# 82 loss is [1.13761462e-07], parameters w:[1.9998211], b:[0.21303716]
# 83 loss is [9.33422577e-08], parameters w:[1.99983808], b:[0.21306421]
# 84 loss is [7.65891057e-08], parameters w:[1.99985345], b:[0.21308873]
# 85 loss is [6.28435769e-08], parameters w:[1.99986735], b:[0.21311095]
# 86 loss is [5.15655505e-08], parameters w:[1.99987993], b:[0.21313109]
# 87 loss is [4.23119435e-08], parameters w:[1.9998913], b:[0.21314934]
# 88 loss is [3.47192674e-08], parameters w:[1.9999016], b:[0.21316589]
# 89 loss is [2.84893226e-08], parameters w:[1.99991092], b:[0.21318088]
# 90 loss is [2.33774661e-08], parameters w:[1.99991935], b:[0.21319447]
# 91 loss is [1.91829879e-08], parameters w:[1.99992698], b:[0.21320678]
# 92 loss is [1.57412189e-08], parameters w:[1.99993389], b:[0.21321794]
# 93 loss is [1.29170562e-08], parameters w:[1.99994014], b:[0.21322806]
# 94 loss is [1.05996526e-08], parameters w:[1.9999458], b:[0.21323722]
# 95 loss is [8.69806055e-09], parameters w:[1.99995092], b:[0.21324553]
# 96 loss is [7.1376586e-09], parameters w:[1.99995556], b:[0.21325305]
# 97 loss is [5.85721963e-09], parameters w:[1.99995976], b:[0.21325987]
# 98 loss is [4.80650606e-09], parameters w:[1.99996356], b:[0.21326605]
# 99 loss is [3.94429683e-09], parameters w:[1.999967], b:[0.21327165]
# 100 loss is [3.23676874e-09], parameters w:[1.99997012], b:[0.21327673]
# 101 loss is [2.65616846e-09], parameters w:[1.99997294], b:[0.21328132]
# 102 loss is [2.17972303e-09], parameters w:[1.99997549], b:[0.21328549]
# 103 loss is [1.78874593e-09], parameters w:[1.9999778], b:[0.21328926]
# 104 loss is [1.46790366e-09], parameters w:[1.9999799], b:[0.21329268]
# 105 loss is [1.204614e-09], parameters w:[1.99998179], b:[0.21329578]
# 106 loss is [9.88552249e-10], parameters w:[1.99998351], b:[0.21329859]
# 107 loss is [8.11246138e-10], parameters w:[1.99998507], b:[0.21330113]
# 108 loss is [6.657434e-10], parameters w:[1.99998647], b:[0.21330344]
# 109 loss is [5.46339047e-10], parameters w:[1.99998775], b:[0.21330553]
# 110 loss is [4.48351561e-10], parameters w:[1.9999889], b:[0.21330742]
# 111 loss is [3.67939272e-10], parameters w:[1.99998995], b:[0.21330913]
# 112 loss is [3.01949668e-10], parameters w:[1.9999909], b:[0.21331068]
# 113 loss is [2.47795758e-10], parameters w:[1.99999176], b:[0.21331209]
# 114 loss is [2.0335461e-10], parameters w:[1.99999253], b:[0.21331337]
# 115 loss is [1.66884105e-10], parameters w:[1.99999324], b:[0.21331452]
# 116 loss is [1.36954616e-10], parameters w:[1.99999387], b:[0.21331557]
# 117 loss is [1.12392953e-10], parameters w:[1.99999445], b:[0.21331652]
# 118 loss is [9.22363601e-11], parameters w:[1.99999497], b:[0.21331737]
# 119 loss is [7.56947671e-11], parameters w:[1.99999545], b:[0.21331815]
# 120 loss is [6.21198143e-11], parameters w:[1.99999588], b:[0.21331886]
# 121 loss is [5.09794326e-11], parameters w:[1.99999626], b:[0.2133195]
# 122 loss is [4.18369842e-11], parameters w:[1.99999662], b:[0.21332007]
# 123 loss is [3.43341452e-11], parameters w:[1.99999693], b:[0.2133206]
# 124 loss is [2.81768587e-11], parameters w:[1.99999722], b:[0.21332107]
# 125 loss is [2.31238076e-11], parameters w:[1.99999748], b:[0.2133215]
# 126 loss is [1.89769553e-11], parameters w:[1.99999772], b:[0.21332189]
# 127 loss is [1.55737828e-11], parameters w:[1.99999794], b:[0.21332225]
# 128 loss is [1.27809184e-11], parameters w:[1.99999813], b:[0.21332257]
# 129 loss is [1.04889099e-11], parameters w:[1.99999831], b:[0.21332286]
# 130 loss is [8.60793495e-12], parameters w:[1.99999847], b:[0.21332312]
# 131 loss is [7.06428002e-12], parameters w:[1.99999861], b:[0.21332336]
# 132 loss is [5.79745154e-12], parameters w:[1.99999874], b:[0.21332357]
# 133 loss is [4.75780482e-12], parameters w:[1.99999886], b:[0.21332377]
# 134 loss is [3.90459843e-12], parameters w:[1.99999897], b:[0.21332395]
# 135 loss is [3.20439742e-12], parameters w:[1.99999906], b:[0.21332411]
# 136 loss is [2.62976294e-12], parameters w:[1.99999915], b:[0.21332425]
# 137 loss is [2.15817693e-12], parameters w:[1.99999923], b:[0.21332438]
# 138 loss is [1.77115959e-12], parameters w:[1.9999993], b:[0.2133245]
# 139 loss is [1.45354519e-12], parameters w:[1.99999937], b:[0.21332461]
# 140 loss is [1.19288771e-12], parameters w:[1.99999943], b:[0.21332471]
# 141 loss is [9.789731e-13], parameters w:[1.99999948], b:[0.2133248]
# 142 loss is [8.03419034e-13], parameters w:[1.99999953], b:[0.21332488]
# 143 loss is [6.59346382e-13], parameters w:[1.99999958], b:[0.21332495]
# 144 loss is [5.41109655e-13], parameters w:[1.99999962], b:[0.21332501]
# 145 loss is [4.44075766e-13], parameters w:[1.99999965], b:[0.21332507]
# 146 loss is [3.64442479e-13], parameters w:[1.99999968], b:[0.21332513]
# 147 loss is [2.99089408e-13], parameters w:[1.99999971], b:[0.21332518]
# 148 loss is [2.45455737e-13], parameters w:[1.99999974], b:[0.21332522]
# 149 loss is [2.01439877e-13], parameters w:[1.99999977], b:[0.21332526]
# 150 loss is [1.65317113e-13], parameters w:[1.99999979], b:[0.2133253]
# 151 loss is [1.35672013e-13], parameters w:[1.99999981], b:[0.21332533]
# 152 loss is [1.11342974e-13], parameters w:[1.99999983], b:[0.21332536]
# 153 loss is [9.13766967e-14], parameters w:[1.99999984], b:[0.21332539]
# 154 loss is [7.49908315e-14], parameters w:[1.99999986], b:[0.21332541]
# 155 loss is [6.15433255e-14], parameters w:[1.99999987], b:[0.21332543]
# 156 loss is [5.05072615e-14], parameters w:[1.99999988], b:[0.21332545]
# 157 loss is [4.14502116e-14], parameters w:[1.99999989], b:[0.21332547]
# 158 loss is [3.40172926e-14], parameters w:[1.9999999], b:[0.21332549]
# 159 loss is [2.79172605e-14], parameters w:[1.99999991], b:[0.2133255]
# 160 loss is [2.29110983e-14], parameters w:[1.99999992], b:[0.21332552]
# 161 loss is [1.88026504e-14], parameters w:[1.99999993], b:[0.21332553]
# 162 loss is [1.54309365e-14], parameters w:[1.99999994], b:[0.21332554]
# 163 loss is [1.26638439e-14], parameters w:[1.99999994], b:[0.21332555]
# 164 loss is [1.03929504e-14], parameters w:[1.99999995], b:[0.21332556]
# 165 loss is [8.5292767e-15], parameters w:[1.99999995], b:[0.21332557]
# 166 loss is [6.99979936e-15], parameters w:[1.99999996], b:[0.21332558]
# 167 loss is [5.74458975e-15], parameters w:[1.99999996], b:[0.21332558]
# 168 loss is [4.71446571e-15], parameters w:[1.99999996], b:[0.21332559]
# 169 loss is [3.86906455e-15], parameters w:[1.99999997], b:[0.21332559]
# 170 loss is [3.17526154e-15], parameters w:[1.99999997], b:[0.2133256]
# 171 loss is [2.60587188e-15], parameters w:[1.99999997], b:[0.2133256]
# 172 loss is [2.13858562e-15], parameters w:[1.99999998], b:[0.21332561]
# 173 loss is [1.75509347e-15], parameters w:[1.99999998], b:[0.21332561]
# 174 loss is [1.44036942e-15], parameters w:[1.99999998], b:[0.21332562]
# 175 loss is [1.18208185e-15], parameters w:[1.99999998], b:[0.21332562]
# 176 loss is [9.70110565e-16], parameters w:[1.99999998], b:[0.21332562]
# 177 loss is [7.96150064e-16], parameters w:[1.99999999], b:[0.21332562]
# 178 loss is [6.53384255e-16], parameters w:[1.99999999], b:[0.21332563]
# 179 loss is [5.36219263e-16], parameters w:[1.99999999], b:[0.21332563]
# 180 loss is [4.40064342e-16], parameters w:[1.99999999], b:[0.21332563]
# 181 loss is [3.61151949e-16], parameters w:[1.99999999], b:[0.21332563]
# 182 loss is [2.96390138e-16], parameters w:[1.99999999], b:[0.21332563]
# 183 loss is [2.43241437e-16], parameters w:[1.99999999], b:[0.21332564]
# 184 loss is [1.99623365e-16], parameters w:[1.99999999], b:[0.21332564]
# 185 loss is [1.638269e-16], parameters w:[1.99999999], b:[0.21332564]
# 186 loss is [1.3444946e-16], parameters w:[1.99999999], b:[0.21332564]
# 187 loss is [1.10339989e-16], parameters w:[1.99999999], b:[0.21332564]
# 188 loss is [9.05538297e-17], parameters w:[2.], b:[0.21332564]
# 189 loss is [7.43157195e-17], parameters w:[2.], b:[0.21332564]
# 190 loss is [6.09894334e-17], parameters w:[2.], b:[0.21332564]
# 191 loss is [5.00528145e-17], parameters w:[2.], b:[0.21332564]
# 192 loss is [4.10773498e-17], parameters w:[2.], b:[0.21332564]
# 193 loss is [3.3711363e-17], parameters w:[2.], b:[0.21332564]
# 194 loss is [2.76662467e-17], parameters w:[2.], b:[0.21332564]
# 195 loss is [2.27051397e-17], parameters w:[2.], b:[0.21332564]
# 196 loss is [1.8633658e-17], parameters w:[2.], b:[0.21332564]
# 197 loss is [1.52922721e-17], parameters w:[2.], b:[0.21332565]
# 198 loss is [1.25500666e-17], parameters w:[2.], b:[0.21332565]
# 199 loss is [1.02995912e-17], parameters w:[2.], b:[0.21332565]
# 200 loss is [8.45267043e-18], parameters w:[2.], b:[0.21332565]
# 201 loss is [6.93693896e-18], parameters w:[2.], b:[0.21332565]
# 202 loss is [5.69300754e-18], parameters w:[2.], b:[0.21332565]
# 203 loss is [4.67213864e-18], parameters w:[2.], b:[0.21332565]
# 204 loss is [3.83433167e-18], parameters w:[2.], b:[0.21332565]
# 205 loss is [3.14676017e-18], parameters w:[2.], b:[0.21332565]
# 206 loss is [2.5824834e-18], parameters w:[2.], b:[0.21332565]
# 207 loss is [2.11939361e-18], parameters w:[2.], b:[0.21332565]
# 208 loss is [1.73934478e-18], parameters w:[2.], b:[0.21332565]
# 209 loss is [1.42744568e-18], parameters w:[2.], b:[0.21332565]
# 210 loss is [1.17147716e-18], parameters w:[2.], b:[0.21332565]
# 211 loss is [9.61408162e-19], parameters w:[2.], b:[0.21332565]
# 212 loss is [7.89009279e-19], parameters w:[2.], b:[0.21332565]
# 213 loss is [6.4752434e-19], parameters w:[2.], b:[0.21332565]
# 214 loss is [5.31410579e-19], parameters w:[2.], b:[0.21332565]
# 215 loss is [4.3611802e-19], parameters w:[2.], b:[0.21332565]
# 216 loss is [3.5791338e-19], parameters w:[2.], b:[0.21332565]
# 217 loss is [2.93732385e-19], parameters w:[2.], b:[0.21332565]
# 218 loss is [2.41060488e-19], parameters w:[2.], b:[0.21332565]
# 219 loss is [1.9783386e-19], parameters w:[2.], b:[0.21332565]
# 220 loss is [1.62358447e-19], parameters w:[2.], b:[0.21332565]
# 221 loss is [1.33244563e-19], parameters w:[2.], b:[0.21332565]
# 222 loss is [1.09351087e-19], parameters w:[2.], b:[0.21332565]
# 223 loss is [8.97423604e-20], parameters w:[2.], b:[0.21332565]
# 224 loss is [7.36497938e-20], parameters w:[2.], b:[0.21332565]
# 225 loss is [6.04429498e-20], parameters w:[2.], b:[0.21332565]
# 226 loss is [4.96042847e-20], parameters w:[2.], b:[0.21332565]
# 227 loss is [4.07093052e-20], parameters w:[2.], b:[0.21332565]
# 228 loss is [3.34093043e-20], parameters w:[2.], b:[0.21332565]
# 229 loss is [2.74184041e-20], parameters w:[2.], b:[0.21332565]
# 230 loss is [2.25016615e-20], parameters w:[2.], b:[0.21332565]
# 231 loss is [1.84666811e-20], parameters w:[2.], b:[0.21332565]
# 232 loss is [1.5155228e-20], parameters w:[2.], b:[0.21332565]
# 233 loss is [1.24376347e-20], parameters w:[2.], b:[0.21332565]
# 234 loss is [1.02073765e-20], parameters w:[2.], b:[0.21332565]
# 235 loss is [8.37697861e-21], parameters w:[2.], b:[0.21332565]
# 236 loss is [6.87483211e-21], parameters w:[2.], b:[0.21332565]
# 237 loss is [5.64205469e-21], parameters w:[2.], b:[0.21332565]
# 238 loss is [4.6303173e-21], parameters w:[2.], b:[0.21332565]
# 239 loss is [3.80002871e-21], parameters w:[2.], b:[0.21332565]
# 240 loss is [3.11860498e-21], parameters w:[2.], b:[0.21332565]
# 241 loss is [2.55935999e-21], parameters w:[2.], b:[0.21332565]
# 242 loss is [2.10042629e-21], parameters w:[2.], b:[0.21332565]
# 243 loss is [1.72378085e-21], parameters w:[2.], b:[0.21332565]
# 244 loss is [1.41468001e-21], parameters w:[2.], b:[0.21332565]
# 245 loss is [1.16099786e-21], parameters w:[2.], b:[0.21332565]
# 246 loss is [9.52811146e-22], parameters w:[2.], b:[0.21332565]
# 247 loss is [7.81952072e-22], parameters w:[2.], b:[0.21332565]
# 248 loss is [6.41736154e-22], parameters w:[2.], b:[0.21332565]
# 249 loss is [5.26655969e-22], parameters w:[2.], b:[0.21332565]
# 250 loss is [4.32215877e-22], parameters w:[2.], b:[0.21332565]
# 251 loss is [3.54715137e-22], parameters w:[2.], b:[0.21332565]
# 252 loss is [2.91110644e-22], parameters w:[2.], b:[0.21332565]
# 253 loss is [2.38906113e-22], parameters w:[2.], b:[0.21332565]
# 254 loss is [1.96067988e-22], parameters w:[2.], b:[0.21332565]
# 255 loss is [1.6091435e-22], parameters w:[2.], b:[0.21332565]
# 256 loss is [1.32055785e-22], parameters w:[2.], b:[0.21332565]
# 257 loss is [1.08376878e-22], parameters w:[2.], b:[0.21332565]
# 258 loss is [8.89412494e-23], parameters w:[2.], b:[0.21332565]
# 259 loss is [7.2990247e-23], parameters w:[2.], b:[0.21332565]
# 260 loss is [5.99045493e-23], parameters w:[2.], b:[0.21332565]
# 261 loss is [4.91604902e-23], parameters w:[2.], b:[0.21332565]
# 262 loss is [4.03437327e-23], parameters w:[2.], b:[0.21332565]
# 263 loss is [3.31092143e-23], parameters w:[2.], b:[0.21332565]
# 264 loss is [2.71753046e-23], parameters w:[2.], b:[0.21332565]
# 265 loss is [2.23018945e-23], parameters w:[2.], b:[0.21332565]
# 266 loss is [1.83037081e-23], parameters w:[2.], b:[0.21332565]
# 267 loss is [1.5020625e-23], parameters w:[2.], b:[0.21332565]
# 268 loss is [1.23276407e-23], parameters w:[2.], b:[0.21332565]
# 269 loss is [1.01168429e-23], parameters w:[2.], b:[0.21332565]
# 270 loss is [8.30229465e-24], parameters w:[2.], b:[0.21332565]
# 271 loss is [6.81379945e-24], parameters w:[2.], b:[0.21332565]
# 272 loss is [5.59226856e-24], parameters w:[2.], b:[0.21332565]
# 273 loss is [4.58942444e-24], parameters w:[2.], b:[0.21332565]
# 274 loss is [3.76757885e-24], parameters w:[2.], b:[0.21332565]
# 275 loss is [3.09225688e-24], parameters w:[2.], b:[0.21332565]
# 276 loss is [2.53721984e-24], parameters w:[2.], b:[0.21332565]
# 277 loss is [2.08254026e-24], parameters w:[2.], b:[0.21332565]
# 278 loss is [1.70926943e-24], parameters w:[2.], b:[0.21332565]
# 279 loss is [1.40364714e-24], parameters w:[2.], b:[0.21332565]
# 280 loss is [1.15182078e-24], parameters w:[2.], b:[0.21332565]
# 281 loss is [9.45350882e-25], parameters w:[2.], b:[0.21332565]
# 282 loss is [7.75498382e-25], parameters w:[2.], b:[0.21332565]
# 283 loss is [6.36769068e-25], parameters w:[2.], b:[0.21332565]
# 284 loss is [5.2197005e-25], parameters w:[2.], b:[0.21332565]
# 285 loss is [4.28587689e-25], parameters w:[2.], b:[0.21332565]
# 286 loss is [3.51699393e-25], parameters w:[2.], b:[0.21332565]
# 287 loss is [2.88275027e-25], parameters w:[2.], b:[0.21332565]
# 288 loss is [2.36651364e-25], parameters w:[2.], b:[0.21332565]
# 289 loss is [1.94318964e-25], parameters w:[2.], b:[0.21332565]
# 290 loss is [1.59480607e-25], parameters w:[2.], b:[0.21332565]
# 291 loss is [1.31018866e-25], parameters w:[2.], b:[0.21332565]
# 292 loss is [1.07582564e-25], parameters w:[2.], b:[0.21332565]
# 293 loss is [8.82321978e-26], parameters w:[2.], b:[0.21332565]
# 294 loss is [7.24095462e-26], parameters w:[2.], b:[0.21332565]
# 295 loss is [5.94045677e-26], parameters w:[2.], b:[0.21332565]
# 296 loss is [4.88297024e-26], parameters w:[2.], b:[0.21332565]
# 297 loss is [4.0090244e-26], parameters w:[2.], b:[0.21332565]
# 298 loss is [3.28763625e-26], parameters w:[2.], b:[0.21332565]
# 299 loss is [2.6954788e-26], parameters w:[2.], b:[0.21332565]
# 300 loss is [2.20394896e-26], parameters w:[2.], b:[0.21332565]
# 301 loss is [1.80797712e-26], parameters w:[2.], b:[0.21332565]
# 302 loss is [1.48333793e-26], parameters w:[2.], b:[0.21332565]
# 303 loss is [1.21681785e-26], parameters w:[2.], b:[0.21332565]
# 304 loss is [9.9730039e-27], parameters w:[2.], b:[0.21332565]
# 305 loss is [8.09388052e-27], parameters w:[2.], b:[0.21332565]
# 306 loss is [6.69080296e-27], parameters w:[2.], b:[0.21332565]
# 307 loss is [5.46360009e-27], parameters w:[2.], b:[0.21332565]
# 308 loss is [4.47326904e-27], parameters w:[2.], b:[0.21332565]
# 309 loss is [3.6653214e-27], parameters w:[2.], b:[0.21332565]
# 310 loss is [2.99197808e-27], parameters w:[2.], b:[0.21332565]
# 311 loss is [2.45779846e-27], parameters w:[2.], b:[0.21332565]
# 312 loss is [2.01236445e-27], parameters w:[2.], b:[0.21332565]
# 313 loss is [1.63535056e-27], parameters w:[2.], b:[0.21332565]
# 314 loss is [1.34245391e-27], parameters w:[2.], b:[0.21332565]
# 315 loss is [1.09567264e-27], parameters w:[2.], b:[0.21332565]
# 316 loss is [9.02072306e-28], parameters w:[2.], b:[0.21332565]
# 317 loss is [7.52096289e-28], parameters w:[2.], b:[0.21332565]
# 318 loss is [6.18025681e-28], parameters w:[2.], b:[0.21332565]
# 319 loss is [5.12530326e-28], parameters w:[2.], b:[0.21332565]
# 320 loss is [4.27152465e-28], parameters w:[2.], b:[0.21332565]
# 321 loss is [3.49792019e-28], parameters w:[2.], b:[0.21332565]
# 322 loss is [2.9207575e-28], parameters w:[2.], b:[0.21332565]
# 323 loss is [2.39791528e-28], parameters w:[2.], b:[0.21332565]
# 324 loss is [1.92962773e-28], parameters w:[2.], b:[0.21332565]
# 325 loss is [1.57799298e-28], parameters w:[2.], b:[0.21332565]
# 326 loss is [1.31400808e-28], parameters w:[2.], b:[0.21332565]
# 327 loss is [1.1064637e-28], parameters w:[2.], b:[0.21332565]
# 328 loss is [9.33234777e-29], parameters w:[2.], b:[0.21332565]
# 329 loss is [7.93187314e-29], parameters w:[2.], b:[0.21332565]
# 330 loss is [6.4934654e-29], parameters w:[2.], b:[0.21332565]
# 331 loss is [5.32690652e-29], parameters w:[2.], b:[0.21332565]
# 332 loss is [4.54519467e-29], parameters w:[2.], b:[0.21332565]
# 333 loss is [4.10072085e-29], parameters w:[2.], b:[0.21332565]
# 334 loss is [3.78419041e-29], parameters w:[2.], b:[0.21332565]
# 335 loss is [3.44769193e-29], parameters w:[2.], b:[0.21332565]
# 336 loss is [3.35663397e-29], parameters w:[2.], b:[0.21332565]
# 337 loss is [3.14881842e-29], parameters w:[2.], b:[0.21332565]
# 338 loss is [2.78640463e-29], parameters w:[2.], b:[0.21332565]
# 339 loss is [2.79133501e-29], parameters w:[2.], b:[0.21332565]
# 340 loss is [2.30211799e-29], parameters w:[2.], b:[0.21332565]
# 341 loss is [2.27056355e-29], parameters w:[2.], b:[0.21332565]
# 342 loss is [2.09454896e-29], parameters w:[2.], b:[0.21332565]
# 343 loss is [2.08283931e-29], parameters w:[2.], b:[0.21332565]
# 344 loss is [2.17540721e-29], parameters w:[2.], b:[0.21332565]
# 345 loss is [2.02666378e-29], parameters w:[2.], b:[0.21332565]
# 346 loss is [2.01775828e-29], parameters w:[2.], b:[0.21332565]
# 347 loss is [2.0082673e-29], parameters w:[2.], b:[0.21332565]
# 348 loss is [2.01162612e-29], parameters w:[2.], b:[0.21332565]
# 349 loss is [1.89548484e-29], parameters w:[2.], b:[0.21332565]
# 350 loss is [1.89289639e-29], parameters w:[2.], b:[0.21332565]
# 351 loss is [1.88562408e-29], parameters w:[2.], b:[0.21332565]
# 352 loss is [2.00395322e-29], parameters w:[2.], b:[0.21332565]
# 353 loss is [2.00395322e-29], parameters w:[2.], b:[0.21332565]
# 354 loss is [1.99732802e-29], parameters w:[2.], b:[0.21332565]
# 355 loss is [1.99742046e-29], parameters w:[2.], b:[0.21332565]
# 356 loss is [1.99742046e-29], parameters w:[2.], b:[0.21332565]
# 357 loss is [2.00382996e-29], parameters w:[2.], b:[0.21332565]
# 358 loss is [2.00423055e-29], parameters w:[2.], b:[0.21332565]
# 359 loss is [1.99803676e-29], parameters w:[2.], b:[0.21332565]
# 360 loss is [1.95662156e-29], parameters w:[2.], b:[0.21332565]
# 361 loss is [1.90928991e-29], parameters w:[2.], b:[0.21332565]
# 362 loss is [1.90340427e-29], parameters w:[2.], b:[0.21332565]
# 363 loss is [1.90423627e-29], parameters w:[2.], b:[0.21332565]
# 364 loss is [1.91163184e-29], parameters w:[2.], b:[0.21332565]
# 365 loss is [1.91163184e-29], parameters w:[2.], b:[0.21332565]
# 366 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 367 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 368 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 369 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 370 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 371 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 372 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 373 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 374 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 375 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 376 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 377 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 378 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 379 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 380 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 381 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 382 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 383 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 384 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 385 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 386 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 387 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 388 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 389 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 390 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 391 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 392 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 393 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 394 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 395 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 396 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 397 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 398 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
# 399 loss is [1.91277199e-29], parameters w:[2.], b:[0.21332565]
